# %% [markdown]
# # Ecommerce Sales Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df = pd.read_csv(r'E:\DA\Ecommerce.csv')
df.head()
# Out:
#    ord_id       created_at   ord_date  ord_time  year_ord  month_ord  day_ord  \
# 0  #25491  8/19/2022 11:16  8/19/2022  11:16:49      2022          8       19
# 1  #25489   8/19/2022 5:35  8/19/2022   5:35:36      2022          8       19
# 2  #25485   8/17/2022 9:50  8/17/2022   9:50:06      2022          8       17
# 3  #25478  8/13/2022 10:14  8/13/2022  10:14:45      2022          8       13
# 4  #25467   8/6/2022 19:32   8/6/2022  19:32:35      2022          8        6
#
#    hour_ord                       vendor  \
# 0        11     Support Awareness Hoodie
# 1         5     Support Awareness Hoodie
# 2         9  Support-Awarenesss-Stickers
# 3        10     Support Awareness Hoodie
# 4        19  Support-Awarenesss-Stickers
#
#                                        lineitem_name  lineitem_price  \
# 0  Suicide Prevention Awareness Hoodie Full Print...           39.00
# 1  Multiple Sclerosis Awareness Hoodie 3D : I���m...           42.95
# ...

# %%
df.columns
# Out:
# Index(['ord_id', 'created_at', 'ord_date', 'ord_time', 'year_ord', 'month_ord',
#        'day_ord', 'hour_ord', 'vendor', 'lineitem_name', 'lineitem_price',
#        'lineitem_quantity', 'billing_name', 'billing_address_1',
#        'billing_city', 'billing_province', 'billing_country'],
#       dtype='object')

# %%
df.shape
# Out:
# (2151, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2151 entries, 0 to 2150
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ord_id             2151 non-null   object
#  1   created_at         2151 non-null   object
#  2   ord_date           2151 non-null   object
#  3   ord_time           2151 non-null   object
#  4   year_ord           2151 non-null   int64
#  5   month_ord          2151 non-null   int64
#  6   day_ord            2151 non-null   int64
#  7   hour_ord           2151 non-null   int64
#  8   vendor             2151 non-null   object
#  9   lineitem_name      2151 non-null   object
#  10  lineitem_price     2151 non-null   float64
#  11  lineitem_quantity  2151 non-null   int64
#  12  billing_name       2151 non-null   object
#  13  billing_address_1  2151 non-null   object
#  14  billing_city       2151 non-null   object
#  15  billing_province   2151 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ord_id               0
# created_at           0
# ord_date             0
# ord_time             0
# year_ord             0
# month_ord            0
# day_ord              0
# hour_ord             0
# vendor               0
# lineitem_name        0
# lineitem_price       0
# lineitem_quantity    0
# billing_name         0
# billing_address_1    0
# billing_city         0
# billing_province     0
# billing_country      0
# dtype: int64

# %%
# removing unwanted cells 

df = df.drop(['ord_id', 'ord_date', 'ord_time', 'year_ord', 'month_ord', 'vendor', 'lineitem_price', 'lineitem_quantity', 'billing_name', 'billing_address_1'], axis = 1)
df.head()
# Out:
#         created_at  day_ord  hour_ord  \
# 0  8/19/2022 11:16       19        11
# 1   8/19/2022 5:35       19         5
# 2   8/17/2022 9:50       17         9
# 3  8/13/2022 10:14       13        10
# 4   8/6/2022 19:32        6        19
#
#                                        lineitem_name  billing_city  \
# 0  Suicide Prevention Awareness Hoodie Full Print...       Red Oak
# 1  Multiple Sclerosis Awareness Hoodie 3D : I���m...    Marshfield
# 2  Proud Autism Dad Hoodie Full Print - Hoodie / ...    Kittanning
# 3  Suicide Awareness Hoodie Full Print : Never Gi...  mount morris
# 4  Personalized Photo Name Dates Dog Sticker : In...       Slocomb
#
#   billing_province billing_country
# 0               TX              US
# 1               WI              US
# 2               PA              US
# 3               MI              US
# 4               AL              US

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2151 entries, 0 to 2150
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   created_at        2151 non-null   object
#  1   day_ord           2151 non-null   int64
#  2   hour_ord          2151 non-null   int64
#  3   lineitem_name     2151 non-null   object
#  4   billing_city      2151 non-null   object
#  5   billing_province  2151 non-null   object
#  6   billing_country   2151 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 117.8+ KB

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (2151, 7)

# %%
df.columns
# Out:
# Index(['created_at', 'day_ord', 'hour_ord', 'lineitem_name', 'billing_city',
#        'billing_province', 'billing_country'],
#       dtype='object')

# %%
g = sns.countplot(df['billing_city'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(df['day_ord'])
plt.xticks(rotation = 90)
plt.show()

# %%
g = sns.countplot(df['hour_ord'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(df,['billing_province'])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\1758879016.py:1: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.hist(df,['billing_province'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\1758879016.py:1: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.hist(df,['billing_province'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12316\1758879016.py:1: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.hist(df,['billing_province'])
# ...

# %%
sns.boxplot( x= 'day_ord', y= 'hour_ord', data= df)
plt.show()

# %%
df1 = df.groupby(['billing_province', 'day_ord']).count()

# %%
df1.to_csv('billing_provice_day.csv')

# %%
df1 = pd.read_csv('billing_provice_day.csv')
df.head()
# Out:
#         created_at  day_ord  hour_ord  \
# 0  8/19/2022 11:16       19        11
# 1   8/19/2022 5:35       19         5
# 2   8/17/2022 9:50       17         9
# 3  8/13/2022 10:14       13        10
# 4   8/6/2022 19:32        6        19
#
#                                        lineitem_name  billing_city  \
# 0  Suicide Prevention Awareness Hoodie Full Print...       Red Oak
# 1  Multiple Sclerosis Awareness Hoodie 3D : I���m...    Marshfield
# 2  Proud Autism Dad Hoodie Full Print - Hoodie / ...    Kittanning
# 3  Suicide Awareness Hoodie Full Print : Never Gi...  mount morris
# 4  Personalized Photo Name Dates Dog Sticker : In...       Slocomb
#
#   billing_province billing_country
# 0               TX              US
# 1               WI              US
# 2               PA              US
# 3               MI              US
# 4               AL              US

# %%
df1 = pd.pivot_table(df1, values = None, index= ['billing_province'], columns = ['day_ord'], fill_value = 0, aggfunc = np.sum)

# %%
df1.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='billing_province'>
